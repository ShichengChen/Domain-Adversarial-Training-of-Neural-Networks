# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import time
import os
import torch.nn as nn
from torch.autograd import Function
import torchvision
import torch.utils.data as data
from PIL import Image
import os

# %%
class GRL(Function):
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x) * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
class Dann(nn.Module):
    def __init__(self):
        super(Dann, self).__init__()
        self.f = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=5),
                nn.BatchNorm2d(64),
                nn.MaxPool2d(2,2),
                nn.ReLU(),
                #nn.Conv2d(32, 32, kernel_size=3,padding=1,stride=2),
                #nn.BatchNorm2d(32),
                nn.Conv2d(64, 50, kernel_size=5),
                nn.BatchNorm2d(50),
                nn.Dropout2d(),
                nn.MaxPool2d(2, 2),
                nn.ReLU(),

                #nn.Conv2d(32, 32, kernel_size=3,padding=1,stride=2),
                #nn.BatchNorm2d(32),
                #nn.ReLU(),
                #nn.Conv2d(32, 128, kernel_size=5,padding=2),
                #nn.AvgPool2d(7)
            )
        self.lc = nn.Sequential(
            nn.Linear(50*4*4, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(),
            nn.Dropout2d(),
            nn.Linear(100, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(),
            nn.Linear(100, 10),
        )
        self.dc = nn.Sequential(
            nn.Linear(50 * 4 * 4, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(),
            nn.Linear(100, 2),
        )
    def forward(self, x,alpha):
        x = self.f(x)
        x = x.view(-1, 50*4*4)
        y = GRL.apply(x, alpha)
        x = self.lc(x)
        y = self.dc(y)
        x=x.view(x.shape[0],-1)
        y=y.view(y.shape[0],-1)
        return x, y

# %%
source_train = torch.utils.data.DataLoader(
        datasets.MNIST('./', train=True, download=False,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.5,), (0.5,)),
                           transforms.Lambda(lambda x: x.repeat(3, 1, 1))
                       ])),
        batch_size=512, shuffle=True,num_workers=12)
source_test = torch.utils.data.DataLoader(
        datasets.MNIST('./', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.5,), (0.5,)),
                           transforms.Lambda(lambda x: x.repeat(3, 1, 1))
                       ])),
        batch_size=512, shuffle=False,num_workers=12)

# %%
class GetLoader(data.Dataset):
    def __init__(self, data_root, data_list, transform=None):
        self.root = data_root
        self.transform = transform

        f = open(data_list, 'r')
        data_list = f.readlines()
        f.close()

        self.n_data = len(data_list)

        self.img_paths = []
        self.img_labels = []

        for data in data_list:
            self.img_paths.append(data[:-3])
            self.img_labels.append(data[-2])

    def __getitem__(self, item):
        img_paths, labels = self.img_paths[item], self.img_labels[item]
        imgs = Image.open(os.path.join(self.root, img_paths)).convert('RGB')

        if self.transform is not None:
            imgs = self.transform(imgs)
            labels = int(labels)

        return imgs, labels

    def __len__(self):
        return self.n_data

# %%
image_size=28
img_transform = transforms.Compose([
    transforms.RandomCrop((image_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,0.5,0.5),
                         std=(0.5,0.5,0.5))
])
train_list = os.path.join('mnist_m', 'mnist_m_train_labels.txt')
dataset_train_target = GetLoader(
    data_root=os.path.join('mnist_m', 'mnist_m_train'),
    data_list=train_list,
    transform=img_transform
)
test_list = os.path.join('mnist_m', 'mnist_m_test_labels.txt')
dataset_test_target = GetLoader(
    data_root=os.path.join('mnist_m', 'mnist_m_test'),
    data_list=test_list,
    transform=img_transform
)
target_train = torch.utils.data.DataLoader(dataset_train_target,batch_size=512, shuffle=True,num_workers=12)
target_test = torch.utils.data.DataLoader(dataset_test_target,batch_size=512, shuffle=True,num_workers=12)

# %%
device='cuda'
model = Dann().to(device)
#optimizer = optim.Adam(model.parameters(),weight_decay=1e-5)
optimizer = optim.SGD(model.parameters(), lr= 0.01, momentum= 0.9)
#optimizer = optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)
criterion = nn.CrossEntropyLoss()

def optimizer_scheduler(optimizer, p):
    for param_group in optimizer.param_groups:
        param_group['lr'] = 0.01 / (1. + 10 * p) ** 0.75
    return optimizer

# %%
def test(epoch):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in source_test:
            data, target = data.to(device), target.to(device)
            output, _ = model(data,0.5)
            test_loss += float(criterion(output, target))  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += float(pred.eq(target.view_as(pred)).sum())

    test_loss /= len(source_test.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(source_test.dataset),
        100. * correct / len(source_test.dataset)))

    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in target_train:
            data, target = data.to(device), target.to(device)
            output, _ = model(data,0.5)
            test_loss += float(criterion(output, target))  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += float(pred.eq(target.view_as(pred)).sum())

    test_loss /= len(target_train.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(target_train.dataset),
        100. * correct / len(target_train.dataset)))
    
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in target_test:
            data, target = data.to(device), target.to(device)
            output, _ = model(data,0.5)
            test_loss += float(criterion(output, target))  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += float(pred.eq(target.view_as(pred)).sum())

    test_loss /= len(target_test.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(target_test.dataset),
        100. * correct / len(target_test.dataset)))

# %%
print(len(target_train),len(source_train))
# Out:
# 116 118

# %%
allepoch=100

for epoch in range(allepoch):
    len_dataloader = min(len(source_train), len(target_train))
    total_steps = allepoch * len(source_train)
    i = 0
    model.train()
    for batch_idx, (data_source, data_target) in enumerate(zip(source_train, target_train)):
        start_time = time.time()
        s_img, s_label = data_source

        start_steps = epoch * len(source_train)

        p = float(i + start_steps) / total_steps
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        optimizer = optimizer_scheduler(optimizer, p)
        optimizer.zero_grad()


        batch_size = len(s_label)

        domain_label = torch.zeros(batch_size)
        domain_label = domain_label.long()


        a,b = model(s_img.to(device),alpha)
        err_s_label = criterion(a, s_label.to(device))
        err_s_domain = criterion(b, domain_label.to(device))

        # training model using target data
        t_img, _ = data_target

        batch_size = len(t_img)

        domain_label = torch.ones(batch_size)
        domain_label = domain_label.long()



        _, b = model(t_img.to(device),alpha)
        err_t_domain = criterion(b, domain_label.to(device))
        err = err_s_label + err_s_domain + err_t_domain
        err.backward()
        optimizer.step()


        if(i % 1000 == 0):
            print('epoch:{},[{}/{}],s_label:{:.3f},s_domain:{:.3f},t_domain:{:.3f},time{}'.
                      format(epoch, i, len_dataloader, float(err_s_label), float(err_s_domain),
                             float(err_t_domain), time.time() - start_time))

        i += 1

    test(epoch)
# Out:
# epoch:0,[0/116],s_label:2.311,s_domain:0.722,t_domain:0.665,time0.13048028945922852
# Test set: Average loss: 0.0006, Accuracy: 9511.0/10000 (95%)
# Test set: Average loss: 0.0035, Accuracy: 24156.0/59001 (41%)
#
# Test set: Average loss: 0.0036, Accuracy: 3649.0/9001 (41%)
#
# epoch:1,[0/116],s_label:0.590,s_domain:0.686,t_domain:0.696,time0.08186531066894531
# Test set: Average loss: 0.0003, Accuracy: 9581.0/10000 (96%)
# Test set: Average loss: 0.0033, Accuracy: 24618.0/59001 (42%)
#
# Test set: Average loss: 0.0034, Accuracy: 3775.0/9001 (42%)
#
# epoch:2,[0/116],s_label:0.261,s_domain:0.688,t_domain:0.692,time0.09545540809631348
# Test set: Average loss: 0.0002, Accuracy: 9677.0/10000 (97%)
# Test set: Average loss: 0.0034, Accuracy: 24747.0/59001 (42%)
#
# Test set: Average loss: 0.0034, Accuracy: 3756.0/9001 (42%)
#
# epoch:3,[0/116],s_label:0.215,s_domain:0.681,t_domain:0.686,time0.08481979370117188
# Test set: Average loss: 0.0002, Accuracy: 9771.0/10000 (98%)
# Test set: Average loss: 0.0032, Accuracy: 26016.0/59001 (44%)
#
# Test set: Average loss: 0.0033, Accuracy: 3936.0/9001 (44%)
#
# epoch:4,[0/116],s_label:0.129,s_domain:0.666,t_domain:0.672,time0.10046744346618652
# Test set: Average loss: 0.0001, Accuracy: 9812.0/10000 (98%)
# Test set: Average loss: 0.0033, Accuracy: 28191.0/59001 (48%)
#
# Test set: Average loss: 0.0033, Accuracy: 4266.0/9001 (47%)
#
# epoch:5,[0/116],s_label:0.146,s_domain:0.656,t_domain:0.667,time0.07349181175231934
# Test set: Average loss: 0.0001, Accuracy: 9811.0/10000 (98%)
# Test set: Average loss: 0.0032, Accuracy: 30479.0/59001 (52%)
#
# Test set: Average loss: 0.0033, Accuracy: 4606.0/9001 (51%)
#
# epoch:6,[0/116],s_label:0.131,s_domain:0.647,t_domain:0.657,time0.08420419692993164
# Test set: Average loss: 0.0001, Accuracy: 9767.0/10000 (98%)
# Test set: Average loss: 0.0030, Accuracy: 31935.0/59001 (54%)
#
# Test set: Average loss: 0.0030, Accuracy: 4916.0/9001 (55%)
#
# epoch:7,[0/116],s_label:0.154,s_domain:0.642,t_domain:0.643,time0.1325397491455078
# Test set: Average loss: 0.0001, Accuracy: 9782.0/10000 (98%)
# Test set: Average loss: 0.0030, Accuracy: 31736.0/59001 (54%)
#
# Test set: Average loss: 0.0030, Accuracy: 4854.0/9001 (54%)
#
# epoch:8,[0/116],s_label:0.158,s_domain:0.633,t_domain:0.633,time0.09342050552368164
# Test set: Average loss: 0.0001, Accuracy: 9768.0/10000 (98%)
# Test set: Average loss: 0.0029, Accuracy: 33218.0/59001 (56%)
#
# Test set: Average loss: 0.0029, Accuracy: 5061.0/9001 (56%)
#
# epoch:9,[0/116],s_label:0.125,s_domain:0.627,t_domain:0.642,time0.0802145004272461
# Test set: Average loss: 0.0001, Accuracy: 9816.0/10000 (98%)
# Test set: Average loss: 0.0028, Accuracy: 34474.0/59001 (58%)
#
# Test set: Average loss: 0.0028, Accuracy: 5306.0/9001 (59%)
#
# epoch:10,[0/116],s_label:0.161,s_domain:0.634,t_domain:0.642,time0.09508419036865234
# Test set: Average loss: 0.0001, Accuracy: 9846.0/10000 (98%)
# Test set: Average loss: 0.0029, Accuracy: 33875.0/59001 (57%)
#
# Test set: Average loss: 0.0029, Accuracy: 5290.0/9001 (59%)
#
# epoch:11,[0/116],s_label:0.164,s_domain:0.623,t_domain:0.632,time0.08214640617370605
# Test set: Average loss: 0.0001, Accuracy: 9758.0/10000 (98%)
# Test set: Average loss: 0.0029, Accuracy: 33311.0/59001 (56%)
#
# Test set: Average loss: 0.0028, Accuracy: 5189.0/9001 (58%)
#
# epoch:12,[0/116],s_label:0.225,s_domain:0.633,t_domain:0.634,time0.10525727272033691
# Test set: Average loss: 0.0002, Accuracy: 9752.0/10000 (98%)
# Test set: Average loss: 0.0039, Accuracy: 31238.0/59001 (53%)
#
# Test set: Average loss: 0.0039, Accuracy: 4764.0/9001 (53%)
#
# epoch:13,[0/116],s_label:0.159,s_domain:0.626,t_domain:0.639,time0.10958385467529297
# Test set: Average loss: 0.0001, Accuracy: 9812.0/10000 (98%)
# Test set: Average loss: 0.0027, Accuracy: 35091.0/59001 (59%)
#
# Test set: Average loss: 0.0027, Accuracy: 5434.0/9001 (60%)
#
# epoch:14,[0/116],s_label:0.153,s_domain:0.638,t_domain:0.641,time0.08354616165161133
# Test set: Average loss: 0.0001, Accuracy: 9819.0/10000 (98%)
# Test set: Average loss: 0.0026, Accuracy: 35722.0/59001 (61%)
#
# Test set: Average loss: 0.0026, Accuracy: 5554.0/9001 (62%)
#
# epoch:15,[0/116],s_label:0.130,s_domain:0.615,t_domain:0.609,time0.16708016395568848
# Test set: Average loss: 0.0001, Accuracy: 9821.0/10000 (98%)
# Test set: Average loss: 0.0033, Accuracy: 34069.0/59001 (58%)
#
# Test set: Average loss: 0.0033, Accuracy: 5332.0/9001 (59%)
#
# epoch:16,[0/116],s_label:0.222,s_domain:0.645,t_domain:0.644,time0.10103607177734375
# Test set: Average loss: 0.0001, Accuracy: 9810.0/10000 (98%)
# Test set: Average loss: 0.0028, Accuracy: 34725.0/59001 (59%)
#
# Test set: Average loss: 0.0028, Accuracy: 5399.0/9001 (60%)
#
# epoch:17,[0/116],s_label:0.222,s_domain:0.622,t_domain:0.623,time0.07271385192871094
# Test set: Average loss: 0.0001, Accuracy: 9769.0/10000 (98%)
# Test set: Average loss: 0.0026, Accuracy: 36620.0/59001 (62%)
#
# Test set: Average loss: 0.0026, Accuracy: 5703.0/9001 (63%)
#
# epoch:18,[0/116],s_label:0.167,s_domain:0.645,t_domain:0.660,time0.07294607162475586
# Test set: Average loss: 0.0001, Accuracy: 9779.0/10000 (98%)
# Test set: Average loss: 0.0031, Accuracy: 35657.0/59001 (60%)
#
# Test set: Average loss: 0.0030, Accuracy: 5556.0/9001 (62%)
#
# epoch:19,[0/116],s_label:0.130,s_domain:0.648,t_domain:0.638,time0.12043642997741699
# Test set: Average loss: 0.0001, Accuracy: 9786.0/10000 (98%)
# Test set: Average loss: 0.0025, Accuracy: 38020.0/59001 (64%)
#
# Test set: Average loss: 0.0024, Accuracy: 5889.0/9001 (65%)
#
# epoch:20,[0/116],s_label:0.112,s_domain:0.626,t_domain:0.661,time0.08767318725585938
# Test set: Average loss: 0.0002, Accuracy: 9760.0/10000 (98%)
# Test set: Average loss: 0.0029, Accuracy: 36642.0/59001 (62%)
#
# Test set: Average loss: 0.0028, Accuracy: 5702.0/9001 (63%)
#
# epoch:21,[0/116],s_label:0.227,s_domain:0.655,t_domain:0.668,time0.0979306697845459
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7facaefed7b8>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9845.0/10000 (98%)
# Test set: Average loss: 0.0021, Accuracy: 40323.0/59001 (68%)
#
# Test set: Average loss: 0.0021, Accuracy: 6245.0/9001 (69%)
#
# epoch:22,[0/116],s_label:0.161,s_domain:0.625,t_domain:0.643,time0.08194780349731445
# Test set: Average loss: 0.0001, Accuracy: 9796.0/10000 (98%)
# Test set: Average loss: 0.0020, Accuracy: 40438.0/59001 (69%)
#
# Test set: Average loss: 0.0020, Accuracy: 6179.0/9001 (69%)
#
# epoch:23,[0/116],s_label:0.161,s_domain:0.678,t_domain:0.647,time0.0777430534362793
# Test set: Average loss: 0.0001, Accuracy: 9799.0/10000 (98%)
# Test set: Average loss: 0.0020, Accuracy: 41293.0/59001 (70%)
#
# Test set: Average loss: 0.0020, Accuracy: 6406.0/9001 (71%)
#
# epoch:24,[0/116],s_label:0.161,s_domain:0.645,t_domain:0.666,time0.10076546669006348
# Test set: Average loss: 0.0001, Accuracy: 9794.0/10000 (98%)
# Test set: Average loss: 0.0026, Accuracy: 38793.0/59001 (66%)
#
# Test set: Average loss: 0.0026, Accuracy: 6040.0/9001 (67%)
#
# epoch:25,[0/116],s_label:0.136,s_domain:0.621,t_domain:0.662,time0.10918879508972168
# Test set: Average loss: 0.0002, Accuracy: 9780.0/10000 (98%)
# Test set: Average loss: 0.0023, Accuracy: 40393.0/59001 (68%)
#
# Test set: Average loss: 0.0023, Accuracy: 6225.0/9001 (69%)
#
# epoch:26,[0/116],s_label:0.173,s_domain:0.673,t_domain:0.626,time0.09654641151428223
# Test set: Average loss: 0.0001, Accuracy: 9800.0/10000 (98%)
# Test set: Average loss: 0.0023, Accuracy: 39242.0/59001 (67%)
#
# Test set: Average loss: 0.0023, Accuracy: 6103.0/9001 (68%)
#
# epoch:27,[0/116],s_label:0.152,s_domain:0.645,t_domain:0.661,time0.07303738594055176
# Test set: Average loss: 0.0001, Accuracy: 9818.0/10000 (98%)
# Test set: Average loss: 0.0021, Accuracy: 40942.0/59001 (69%)
#
# Test set: Average loss: 0.0021, Accuracy: 6364.0/9001 (71%)
#
# epoch:28,[0/116],s_label:0.144,s_domain:0.629,t_domain:0.631,time0.07300472259521484
# Test set: Average loss: 0.0002, Accuracy: 9759.0/10000 (98%)
# Test set: Average loss: 0.0020, Accuracy: 40338.0/59001 (68%)
#
# Test set: Average loss: 0.0020, Accuracy: 6268.0/9001 (70%)
#
# epoch:29,[0/116],s_label:0.156,s_domain:0.667,t_domain:0.640,time0.08951473236083984
# Test set: Average loss: 0.0001, Accuracy: 9788.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 41125.0/59001 (70%)
#
# Test set: Average loss: 0.0019, Accuracy: 6329.0/9001 (70%)
#
# epoch:30,[0/116],s_label:0.163,s_domain:0.659,t_domain:0.662,time0.0862729549407959
# Test set: Average loss: 0.0001, Accuracy: 9768.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 41663.0/59001 (71%)
#
# Test set: Average loss: 0.0018, Accuracy: 6465.0/9001 (72%)
#
# epoch:31,[0/116],s_label:0.139,s_domain:0.659,t_domain:0.675,time0.07628083229064941
# Test set: Average loss: 0.0001, Accuracy: 9794.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 42621.0/59001 (72%)
#
# Test set: Average loss: 0.0018, Accuracy: 6619.0/9001 (74%)
#
# epoch:32,[0/116],s_label:0.132,s_domain:0.641,t_domain:0.638,time0.10434818267822266
# Test set: Average loss: 0.0001, Accuracy: 9802.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 42530.0/59001 (72%)
#
# Test set: Average loss: 0.0018, Accuracy: 6632.0/9001 (74%)
#
# epoch:33,[0/116],s_label:0.172,s_domain:0.639,t_domain:0.655,time0.14287900924682617
# Test set: Average loss: 0.0001, Accuracy: 9824.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 42713.0/59001 (72%)
#
# Test set: Average loss: 0.0017, Accuracy: 6617.0/9001 (74%)
#
# epoch:34,[0/116],s_label:0.155,s_domain:0.678,t_domain:0.661,time0.08145642280578613
# Test set: Average loss: 0.0001, Accuracy: 9822.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43063.0/59001 (73%)
#
# Test set: Average loss: 0.0017, Accuracy: 6695.0/9001 (74%)
#
# epoch:35,[0/116],s_label:0.122,s_domain:0.652,t_domain:0.659,time0.08083367347717285
# Test set: Average loss: 0.0001, Accuracy: 9805.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 42671.0/59001 (72%)
#
# Test set: Average loss: 0.0018, Accuracy: 6628.0/9001 (74%)
#
# epoch:36,[0/116],s_label:0.142,s_domain:0.663,t_domain:0.680,time0.08886480331420898
# Test set: Average loss: 0.0001, Accuracy: 9797.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 42928.0/59001 (73%)
#
# Test set: Average loss: 0.0018, Accuracy: 6674.0/9001 (74%)
#
# epoch:37,[0/116],s_label:0.166,s_domain:0.665,t_domain:0.665,time0.0725700855255127
# Test set: Average loss: 0.0001, Accuracy: 9808.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43487.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6704.0/9001 (74%)
#
# epoch:38,[0/116],s_label:0.180,s_domain:0.643,t_domain:0.663,time0.11011910438537598
# Test set: Average loss: 0.0001, Accuracy: 9798.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43673.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6765.0/9001 (75%)
#
# epoch:39,[0/116],s_label:0.164,s_domain:0.639,t_domain:0.645,time0.08860921859741211
# Test set: Average loss: 0.0001, Accuracy: 9803.0/10000 (98%)
# Test set: Average loss: 0.0022, Accuracy: 42205.0/59001 (72%)
#
# Test set: Average loss: 0.0022, Accuracy: 6561.0/9001 (73%)
#
# epoch:40,[0/116],s_label:0.129,s_domain:0.621,t_domain:0.645,time0.1205902099609375
# Test set: Average loss: 0.0001, Accuracy: 9810.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43617.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6758.0/9001 (75%)
#
# epoch:41,[0/116],s_label:0.069,s_domain:0.667,t_domain:0.655,time0.07345461845397949
# Test set: Average loss: 0.0001, Accuracy: 9811.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43436.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6734.0/9001 (75%)
#
# epoch:42,[0/116],s_label:0.167,s_domain:0.633,t_domain:0.672,time0.10288596153259277
# Test set: Average loss: 0.0001, Accuracy: 9817.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43708.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6820.0/9001 (76%)
#
# epoch:43,[0/116],s_label:0.163,s_domain:0.635,t_domain:0.664,time0.08523344993591309
# Test set: Average loss: 0.0001, Accuracy: 9811.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43339.0/59001 (73%)
#
# Test set: Average loss: 0.0017, Accuracy: 6750.0/9001 (75%)
#
# epoch:44,[0/116],s_label:0.149,s_domain:0.649,t_domain:0.660,time0.13656187057495117
# Test set: Average loss: 0.0001, Accuracy: 9790.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 42969.0/59001 (73%)
#
# Test set: Average loss: 0.0018, Accuracy: 6636.0/9001 (74%)
#
# epoch:45,[0/116],s_label:0.158,s_domain:0.655,t_domain:0.668,time0.10050177574157715
# Test set: Average loss: 0.0001, Accuracy: 9786.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 44159.0/59001 (75%)
#
# Test set: Average loss: 0.0016, Accuracy: 6826.0/9001 (76%)
#
# epoch:46,[0/116],s_label:0.158,s_domain:0.647,t_domain:0.658,time0.1010887622833252
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7facaefed710>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9817.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43567.0/59001 (74%)
#
# Test set: Average loss: 0.0016, Accuracy: 6826.0/9001 (76%)
#
# epoch:47,[0/116],s_label:0.163,s_domain:0.649,t_domain:0.658,time0.07735347747802734
# Test set: Average loss: 0.0001, Accuracy: 9784.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43642.0/59001 (74%)
#
# Test set: Average loss: 0.0016, Accuracy: 6791.0/9001 (75%)
#
# epoch:48,[0/116],s_label:0.113,s_domain:0.651,t_domain:0.668,time0.09015011787414551
# Test set: Average loss: 0.0001, Accuracy: 9839.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43840.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6810.0/9001 (76%)
#
# epoch:49,[0/116],s_label:0.164,s_domain:0.643,t_domain:0.662,time0.08941030502319336
# Test set: Average loss: 0.0001, Accuracy: 9839.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43697.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6732.0/9001 (75%)
#
# epoch:50,[0/116],s_label:0.099,s_domain:0.655,t_domain:0.662,time0.11236405372619629
# Test set: Average loss: 0.0001, Accuracy: 9841.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 44787.0/59001 (76%)
#
# Test set: Average loss: 0.0016, Accuracy: 6902.0/9001 (77%)
#
# epoch:51,[0/116],s_label:0.138,s_domain:0.659,t_domain:0.670,time0.11730742454528809
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7facaefed748>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 494, in Client
#     deliver_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 722, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9796.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43857.0/59001 (74%)
#
# Test set: Average loss: 0.0018, Accuracy: 6773.0/9001 (75%)
#
# epoch:52,[0/116],s_label:0.111,s_domain:0.690,t_domain:0.664,time0.12810277938842773
# Test set: Average loss: 0.0001, Accuracy: 9828.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43480.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6738.0/9001 (75%)
#
# epoch:53,[0/116],s_label:0.148,s_domain:0.649,t_domain:0.678,time0.12303018569946289
# Test set: Average loss: 0.0001, Accuracy: 9826.0/10000 (98%)
# Test set: Average loss: 0.0020, Accuracy: 43372.0/59001 (74%)
#
# Test set: Average loss: 0.0019, Accuracy: 6663.0/9001 (74%)
#
# epoch:54,[0/116],s_label:0.148,s_domain:0.658,t_domain:0.687,time0.09293246269226074
# Test set: Average loss: 0.0001, Accuracy: 9798.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43307.0/59001 (73%)
#
# Test set: Average loss: 0.0016, Accuracy: 6726.0/9001 (75%)
#
# epoch:55,[0/116],s_label:0.108,s_domain:0.676,t_domain:0.654,time0.10610365867614746
# Test set: Average loss: 0.0001, Accuracy: 9844.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44471.0/59001 (75%)
#
# Test set: Average loss: 0.0016, Accuracy: 6938.0/9001 (77%)
#
# epoch:56,[0/116],s_label:0.159,s_domain:0.650,t_domain:0.670,time0.08070254325866699
# Test set: Average loss: 0.0001, Accuracy: 9830.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43999.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6788.0/9001 (75%)
#
# epoch:57,[0/116],s_label:0.097,s_domain:0.648,t_domain:0.680,time0.08128142356872559
# Test set: Average loss: 0.0001, Accuracy: 9850.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 43716.0/59001 (74%)
#
# Test set: Average loss: 0.0019, Accuracy: 6734.0/9001 (75%)
#
# epoch:58,[0/116],s_label:0.096,s_domain:0.667,t_domain:0.663,time0.10873556137084961
# Test set: Average loss: 0.0001, Accuracy: 9825.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 44094.0/59001 (75%)
#
# Test set: Average loss: 0.0018, Accuracy: 6813.0/9001 (76%)
#
# epoch:59,[0/116],s_label:0.139,s_domain:0.654,t_domain:0.660,time0.07256603240966797
# Test set: Average loss: 0.0001, Accuracy: 9810.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43762.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6790.0/9001 (75%)
#
# epoch:60,[0/116],s_label:0.144,s_domain:0.644,t_domain:0.666,time0.08448219299316406
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7facaefed7b8>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9833.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44392.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6877.0/9001 (76%)
#
# epoch:61,[0/116],s_label:0.115,s_domain:0.633,t_domain:0.673,time0.09624242782592773
# Test set: Average loss: 0.0001, Accuracy: 9820.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 44884.0/59001 (76%)
#
# Test set: Average loss: 0.0016, Accuracy: 6932.0/9001 (77%)
#
# epoch:62,[0/116],s_label:0.124,s_domain:0.664,t_domain:0.667,time0.07787418365478516
# Test set: Average loss: 0.0001, Accuracy: 9829.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 44767.0/59001 (76%)
#
# Test set: Average loss: 0.0016, Accuracy: 6872.0/9001 (76%)
#
# epoch:63,[0/116],s_label:0.135,s_domain:0.676,t_domain:0.679,time0.09090018272399902
# Test set: Average loss: 0.0001, Accuracy: 9837.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44642.0/59001 (76%)
#
# Test set: Average loss: 0.0016, Accuracy: 6900.0/9001 (77%)
#
# epoch:64,[0/116],s_label:0.130,s_domain:0.677,t_domain:0.660,time0.07305026054382324
# Test set: Average loss: 0.0001, Accuracy: 9831.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43976.0/59001 (75%)
#
# Test set: Average loss: 0.0018, Accuracy: 6799.0/9001 (76%)
#
# epoch:65,[0/116],s_label:0.154,s_domain:0.681,t_domain:0.655,time0.08178067207336426
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7facab9683c8>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 494, in Client
#     deliver_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 722, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9854.0/10000 (99%)
# Test set: Average loss: 0.0018, Accuracy: 44191.0/59001 (75%)
#
# Test set: Average loss: 0.0018, Accuracy: 6846.0/9001 (76%)
#
# epoch:66,[0/116],s_label:0.083,s_domain:0.664,t_domain:0.679,time0.09017610549926758
# Test set: Average loss: 0.0001, Accuracy: 9850.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 43616.0/59001 (74%)
#
# Test set: Average loss: 0.0019, Accuracy: 6752.0/9001 (75%)
#
# epoch:67,[0/116],s_label:0.101,s_domain:0.652,t_domain:0.690,time0.14485454559326172
# Test set: Average loss: 0.0001, Accuracy: 9829.0/10000 (98%)
# Test set: Average loss: 0.0020, Accuracy: 43202.0/59001 (73%)
#
# Test set: Average loss: 0.0019, Accuracy: 6665.0/9001 (74%)
#
# epoch:68,[0/116],s_label:0.140,s_domain:0.664,t_domain:0.666,time0.11439847946166992
# Test set: Average loss: 0.0001, Accuracy: 9842.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 43297.0/59001 (73%)
#
# Test set: Average loss: 0.0019, Accuracy: 6674.0/9001 (74%)
#
# epoch:69,[0/116],s_label:0.141,s_domain:0.663,t_domain:0.662,time0.09208536148071289
# Test set: Average loss: 0.0001, Accuracy: 9822.0/10000 (98%)
# Test set: Average loss: 0.0020, Accuracy: 43216.0/59001 (73%)
#
# Test set: Average loss: 0.0020, Accuracy: 6668.0/9001 (74%)
#
# epoch:70,[0/116],s_label:0.152,s_domain:0.666,t_domain:0.691,time0.08005261421203613
# Test set: Average loss: 0.0001, Accuracy: 9802.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43248.0/59001 (73%)
#
# Test set: Average loss: 0.0019, Accuracy: 6664.0/9001 (74%)
#
# epoch:71,[0/116],s_label:0.119,s_domain:0.670,t_domain:0.656,time0.08711123466491699
# Test set: Average loss: 0.0001, Accuracy: 9826.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43708.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6781.0/9001 (75%)
#
# epoch:72,[0/116],s_label:0.119,s_domain:0.662,t_domain:0.638,time0.1146245002746582
# Test set: Average loss: 0.0001, Accuracy: 9816.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43476.0/59001 (74%)
#
# Test set: Average loss: 0.0019, Accuracy: 6661.0/9001 (74%)
#
# epoch:73,[0/116],s_label:0.089,s_domain:0.671,t_domain:0.678,time0.12197089195251465
# Test set: Average loss: 0.0001, Accuracy: 9841.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 43339.0/59001 (73%)
#
# Test set: Average loss: 0.0020, Accuracy: 6688.0/9001 (74%)
#
# epoch:74,[0/116],s_label:0.120,s_domain:0.662,t_domain:0.677,time0.0912160873413086
# Test set: Average loss: 0.0001, Accuracy: 9832.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44239.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6796.0/9001 (76%)
#
# epoch:75,[0/116],s_label:0.101,s_domain:0.636,t_domain:0.669,time0.10122561454772949
# Test set: Average loss: 0.0001, Accuracy: 9825.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 44503.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6850.0/9001 (76%)
#
# epoch:76,[0/116],s_label:0.105,s_domain:0.656,t_domain:0.664,time0.07443428039550781
# Test set: Average loss: 0.0001, Accuracy: 9837.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 44212.0/59001 (75%)
#
# Test set: Average loss: 0.0018, Accuracy: 6801.0/9001 (76%)
#
# epoch:77,[0/116],s_label:0.085,s_domain:0.648,t_domain:0.672,time0.07826614379882812
# Test set: Average loss: 0.0001, Accuracy: 9809.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 44198.0/59001 (75%)
#
# Test set: Average loss: 0.0018, Accuracy: 6795.0/9001 (75%)
#
# epoch:78,[0/116],s_label:0.088,s_domain:0.644,t_domain:0.673,time0.0968015193939209
# Test set: Average loss: 0.0001, Accuracy: 9841.0/10000 (98%)
# Test set: Average loss: 0.0020, Accuracy: 43610.0/59001 (74%)
#
# Test set: Average loss: 0.0019, Accuracy: 6748.0/9001 (75%)
#
# epoch:79,[0/116],s_label:0.101,s_domain:0.650,t_domain:0.671,time0.08939552307128906
# Test set: Average loss: 0.0001, Accuracy: 9853.0/10000 (99%)
# Test set: Average loss: 0.0019, Accuracy: 44484.0/59001 (75%)
#
# Test set: Average loss: 0.0018, Accuracy: 6885.0/9001 (76%)
#
# epoch:80,[0/116],s_label:0.110,s_domain:0.667,t_domain:0.680,time0.08169698715209961
# Test set: Average loss: 0.0001, Accuracy: 9855.0/10000 (99%)
# Test set: Average loss: 0.0019, Accuracy: 44145.0/59001 (75%)
#
# Test set: Average loss: 0.0020, Accuracy: 6714.0/9001 (75%)
#
# epoch:81,[0/116],s_label:0.109,s_domain:0.668,t_domain:0.644,time0.07242584228515625
# Test set: Average loss: 0.0001, Accuracy: 9830.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44251.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6795.0/9001 (75%)
#
# epoch:82,[0/116],s_label:0.153,s_domain:0.672,t_domain:0.643,time0.08503150939941406
# Test set: Average loss: 0.0001, Accuracy: 9838.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 43905.0/59001 (74%)
#
# Test set: Average loss: 0.0019, Accuracy: 6787.0/9001 (75%)
#
# epoch:83,[0/116],s_label:0.110,s_domain:0.667,t_domain:0.658,time0.07317805290222168
# Test set: Average loss: 0.0001, Accuracy: 9797.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43937.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6720.0/9001 (75%)
#
# epoch:84,[0/116],s_label:0.113,s_domain:0.674,t_domain:0.670,time0.08895683288574219
# Test set: Average loss: 0.0001, Accuracy: 9793.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43424.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6679.0/9001 (74%)
#
# epoch:85,[0/116],s_label:0.151,s_domain:0.655,t_domain:0.667,time0.08786511421203613
# Test set: Average loss: 0.0001, Accuracy: 9806.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 44088.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6847.0/9001 (76%)
#
# epoch:86,[0/116],s_label:0.156,s_domain:0.667,t_domain:0.676,time0.1006476879119873
# Test set: Average loss: 0.0001, Accuracy: 9816.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44077.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6814.0/9001 (76%)
#
# epoch:87,[0/116],s_label:0.115,s_domain:0.655,t_domain:0.662,time0.0762476921081543
# Test set: Average loss: 0.0001, Accuracy: 9819.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44313.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6869.0/9001 (76%)
#
# epoch:88,[0/116],s_label:0.076,s_domain:0.657,t_domain:0.652,time0.0749211311340332
# Test set: Average loss: 0.0001, Accuracy: 9820.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44433.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6857.0/9001 (76%)
#
# epoch:89,[0/116],s_label:0.071,s_domain:0.639,t_domain:0.648,time0.09418106079101562
# Test set: Average loss: 0.0001, Accuracy: 9843.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44418.0/59001 (75%)
#
# Test set: Average loss: 0.0017, Accuracy: 6854.0/9001 (76%)
#
# epoch:90,[0/116],s_label:0.130,s_domain:0.651,t_domain:0.659,time0.09969854354858398
# Test set: Average loss: 0.0001, Accuracy: 9839.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 45244.0/59001 (77%)
#
# Test set: Average loss: 0.0015, Accuracy: 6966.0/9001 (77%)
#
# epoch:91,[0/116],s_label:0.124,s_domain:0.661,t_domain:0.672,time0.0947427749633789
# Test set: Average loss: 0.0001, Accuracy: 9858.0/10000 (99%)
# Test set: Average loss: 0.0017, Accuracy: 45130.0/59001 (76%)
#
# Test set: Average loss: 0.0017, Accuracy: 6976.0/9001 (78%)
#
# epoch:92,[0/116],s_label:0.082,s_domain:0.649,t_domain:0.685,time0.10452866554260254
# Test set: Average loss: 0.0001, Accuracy: 9862.0/10000 (99%)
# Test set: Average loss: 0.0017, Accuracy: 44626.0/59001 (76%)
#
# Test set: Average loss: 0.0017, Accuracy: 6891.0/9001 (77%)
#
# epoch:93,[0/116],s_label:0.102,s_domain:0.653,t_domain:0.667,time0.09625554084777832
# Test set: Average loss: 0.0001, Accuracy: 9850.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44923.0/59001 (76%)
#
# Test set: Average loss: 0.0017, Accuracy: 6901.0/9001 (77%)
#
# epoch:94,[0/116],s_label:0.117,s_domain:0.668,t_domain:0.681,time0.07538962364196777
# Test set: Average loss: 0.0001, Accuracy: 9845.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 44801.0/59001 (76%)
#
# Test set: Average loss: 0.0016, Accuracy: 6853.0/9001 (76%)
#
# epoch:95,[0/116],s_label:0.088,s_domain:0.650,t_domain:0.680,time0.09572720527648926
# Test set: Average loss: 0.0001, Accuracy: 9861.0/10000 (99%)
# Test set: Average loss: 0.0016, Accuracy: 44854.0/59001 (76%)
# Test set: Average loss: 0.0016, Accuracy: 6901.0/9001 (77%)
#
# epoch:96,[0/116],s_label:0.074,s_domain:0.672,t_domain:0.669,time0.08373236656188965
# Test set: Average loss: 0.0001, Accuracy: 9833.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 44888.0/59001 (76%)
#
# Test set: Average loss: 0.0016, Accuracy: 6909.0/9001 (77%)
#
# epoch:97,[0/116],s_label:0.087,s_domain:0.664,t_domain:0.675,time0.1050422191619873
# Test set: Average loss: 0.0001, Accuracy: 9842.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 44247.0/59001 (75%)
#
# Test set: Average loss: 0.0016, Accuracy: 6792.0/9001 (75%)
#
# epoch:98,[0/116],s_label:0.087,s_domain:0.646,t_domain:0.650,time0.07918691635131836
# Test set: Average loss: 0.0001, Accuracy: 9826.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44107.0/59001 (75%)
#
# Test set: Average loss: 0.0016, Accuracy: 6794.0/9001 (75%)
#
# epoch:99,[0/116],s_label:0.088,s_domain:0.650,t_domain:0.691,time0.07661056518554688
# Test set: Average loss: 0.0001, Accuracy: 9834.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43776.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6726.0/9001 (75%)
