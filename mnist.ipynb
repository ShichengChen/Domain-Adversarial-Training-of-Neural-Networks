# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import time
import os
import torch.nn as nn
from torch.autograd import Function
import torchvision
import torch.utils.data as data
from PIL import Image
import os

# %%
class GRL(Function):
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x) * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
class Dann(nn.Module):
    def __init__(self):
        super(Dann, self).__init__()
        self.f = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=5),
                nn.BatchNorm2d(64),
                #nn.MaxPool2d(2,2),
                nn.Conv2d(64,64,kernel_size=3,stride=2,padding=1),
                nn.BatchNorm2d(64),
                nn.ReLU(),
                #nn.Conv2d(32, 32, kernel_size=3,padding=1,stride=2),
                #nn.BatchNorm2d(32),
                nn.Conv2d(64, 50, kernel_size=5),
                nn.BatchNorm2d(50),
                nn.Dropout2d(),
                #nn.MaxPool2d(2, 2),
                nn.Conv2d(50, 50, kernel_size=3, stride=2,padding=1),
                nn.BatchNorm2d(50),
                nn.ReLU(),

                #nn.Conv2d(32, 32, kernel_size=3,padding=1,stride=2),
                #nn.BatchNorm2d(32),
                #nn.ReLU(),
                #nn.Conv2d(32, 128, kernel_size=5,padding=2),
                #nn.AvgPool2d(7)
            )
        self.lc = nn.Sequential(
            nn.Linear(50*4*4, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(),
            nn.Dropout2d(),
            nn.Linear(100, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(),
            nn.Linear(100, 10),
        )
        self.dc = nn.Sequential(
            nn.Linear(50 * 4 * 4, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(),
            nn.Linear(100, 2),
        )
    def forward(self, x,alpha):
        x = self.f(x)
        x = x.view(-1, 50*4*4)
        y = GRL.apply(x, alpha)
        x = self.lc(x)
        y = self.dc(y)
        x=x.view(x.shape[0],-1)
        y=y.view(y.shape[0],-1)
        return x, y

# %%
source_train = torch.utils.data.DataLoader(
        datasets.MNIST('./', train=True, download=False,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.5,), (0.5,)),
                           transforms.Lambda(lambda x: x.repeat(3, 1, 1))
                       ])),
        batch_size=512, shuffle=True,num_workers=12)
source_test = torch.utils.data.DataLoader(
        datasets.MNIST('./', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.5,), (0.5,)),
                           transforms.Lambda(lambda x: x.repeat(3, 1, 1))
                       ])),
        batch_size=512, shuffle=False,num_workers=12)

# %%
class GetLoader(data.Dataset):
    def __init__(self, data_root, data_list, transform=None):
        self.root = data_root
        self.transform = transform

        f = open(data_list, 'r')
        data_list = f.readlines()
        f.close()

        self.n_data = len(data_list)

        self.img_paths = []
        self.img_labels = []

        for data in data_list:
            self.img_paths.append(data[:-3])
            self.img_labels.append(data[-2])

    def __getitem__(self, item):
        img_paths, labels = self.img_paths[item], self.img_labels[item]
        imgs = Image.open(os.path.join(self.root, img_paths)).convert('RGB')

        if self.transform is not None:
            imgs = self.transform(imgs)
            labels = int(labels)

        return imgs, labels

    def __len__(self):
        return self.n_data

# %%
image_size=28
img_transform = transforms.Compose([
    transforms.RandomCrop((image_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,0.5,0.5),
                         std=(0.5,0.5,0.5))
])
train_list = os.path.join('mnist_m', 'mnist_m_train_labels.txt')
dataset_train_target = GetLoader(
    data_root=os.path.join('mnist_m', 'mnist_m_train'),
    data_list=train_list,
    transform=img_transform
)
test_list = os.path.join('mnist_m', 'mnist_m_test_labels.txt')
dataset_test_target = GetLoader(
    data_root=os.path.join('mnist_m', 'mnist_m_test'),
    data_list=test_list,
    transform=img_transform
)
target_train = torch.utils.data.DataLoader(dataset_train_target,batch_size=512, shuffle=True,num_workers=12)
target_test = torch.utils.data.DataLoader(dataset_test_target,batch_size=512, shuffle=True,num_workers=12)

# %%
device='cuda'
model = Dann().to(device)
#optimizer = optim.Adam(model.parameters(),weight_decay=1e-5)
optimizer = optim.SGD(model.parameters(), lr= 0.01, momentum= 0.9)
#optimizer = optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)
criterion = nn.CrossEntropyLoss()

def optimizer_scheduler(optimizer, p):
    for param_group in optimizer.param_groups:
        param_group['lr'] = 0.01 / (1. + 10 * p) ** 0.75
    return optimizer

# %%
def test(epoch):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in source_test:
            data, target = data.to(device), target.to(device)
            output, _ = model(data,0.5)
            test_loss += float(criterion(output, target))  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += float(pred.eq(target.view_as(pred)).sum())

    test_loss /= len(source_test.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(source_test.dataset),
        100. * correct / len(source_test.dataset)))

    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in target_train:
            data, target = data.to(device), target.to(device)
            output, _ = model(data,0.5)
            test_loss += float(criterion(output, target))  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += float(pred.eq(target.view_as(pred)).sum())

    test_loss /= len(target_train.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(target_train.dataset),
        100. * correct / len(target_train.dataset)))
    
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in target_test:
            data, target = data.to(device), target.to(device)
            output, _ = model(data,0.5)
            test_loss += float(criterion(output, target))  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += float(pred.eq(target.view_as(pred)).sum())

    test_loss /= len(target_test.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(target_test.dataset),
        100. * correct / len(target_test.dataset)))

# %%
print(len(target_train),len(source_train))
# Out:
# 116 118

# %%
allepoch=100

for epoch in range(allepoch):
    len_dataloader = min(len(source_train), len(target_train))
    total_steps = allepoch * len(source_train)
    i = 0
    model.train()
    for batch_idx, (data_source, data_target) in enumerate(zip(source_train, target_train)):
        start_time = time.time()
        s_img, s_label = data_source

        start_steps = epoch * len(source_train)

        p = float(i + start_steps) / total_steps
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        optimizer = optimizer_scheduler(optimizer, p)
        optimizer.zero_grad()


        batch_size = len(s_label)

        domain_label = torch.zeros(batch_size)
        domain_label = domain_label.long()


        a,b = model(s_img.to(device),alpha)
        err_s_label = criterion(a, s_label.to(device))
        err_s_domain = criterion(b, domain_label.to(device))

        # training model using target data
        t_img, _ = data_target

        batch_size = len(t_img)

        domain_label = torch.ones(batch_size)
        domain_label = domain_label.long()



        _, b = model(t_img.to(device),alpha)
        err_t_domain = criterion(b, domain_label.to(device))
        err = err_s_label + err_s_domain + err_t_domain
        err.backward()
        optimizer.step()


        if(i % 1000 == 0):
            print('epoch:{},[{}/{}],s_label:{:.3f},s_domain:{:.3f},t_domain:{:.3f},time{}'.
                      format(epoch, i, len_dataloader, float(err_s_label), float(err_s_domain),
                             float(err_t_domain), time.time() - start_time))

        i += 1

    test(epoch)
# Out:
# epoch:0,[0/116],s_label:2.322,s_domain:0.684,t_domain:0.702,time0.1462998390197754
# Test set: Average loss: 0.0006, Accuracy: 9394.0/10000 (94%)
# Test set: Average loss: 0.0036, Accuracy: 23400.0/59001 (40%)
#
# Test set: Average loss: 0.0036, Accuracy: 3562.0/9001 (40%)
#
# epoch:1,[0/116],s_label:0.502,s_domain:0.663,t_domain:0.695,time0.11793875694274902
# Test set: Average loss: 0.0003, Accuracy: 9606.0/10000 (96%)
# Test set: Average loss: 0.0036, Accuracy: 23301.0/59001 (39%)
#
# Test set: Average loss: 0.0037, Accuracy: 3594.0/9001 (40%)
#
# epoch:2,[0/116],s_label:0.229,s_domain:0.665,t_domain:0.677,time0.1772465705871582
# Test set: Average loss: 0.0002, Accuracy: 9779.0/10000 (98%)
# Test set: Average loss: 0.0032, Accuracy: 30049.0/59001 (51%)
#
# Test set: Average loss: 0.0032, Accuracy: 4694.0/9001 (52%)
#
# epoch:3,[0/116],s_label:0.135,s_domain:0.654,t_domain:0.661,time0.14191651344299316
# Test set: Average loss: 0.0001, Accuracy: 9793.0/10000 (98%)
# Test set: Average loss: 0.0028, Accuracy: 33607.0/59001 (57%)
#
# Test set: Average loss: 0.0028, Accuracy: 5227.0/9001 (58%)
#
# epoch:4,[0/116],s_label:0.177,s_domain:0.656,t_domain:0.657,time0.11970043182373047
# Test set: Average loss: 0.0001, Accuracy: 9809.0/10000 (98%)
# Test set: Average loss: 0.0028, Accuracy: 34292.0/59001 (58%)
#
# Test set: Average loss: 0.0029, Accuracy: 5210.0/9001 (58%)
#
# epoch:5,[0/116],s_label:0.180,s_domain:0.643,t_domain:0.662,time0.13927221298217773
# Test set: Average loss: 0.0002, Accuracy: 9706.0/10000 (97%)
# Test set: Average loss: 0.0028, Accuracy: 35416.0/59001 (60%)
#
# Test set: Average loss: 0.0028, Accuracy: 5455.0/9001 (61%)
#
# epoch:6,[0/116],s_label:0.169,s_domain:0.648,t_domain:0.657,time0.11971426010131836
# Test set: Average loss: 0.0002, Accuracy: 9759.0/10000 (98%)
# Test set: Average loss: 0.0024, Accuracy: 38571.0/59001 (65%)
#
# Test set: Average loss: 0.0024, Accuracy: 5932.0/9001 (66%)
#
# epoch:7,[0/116],s_label:0.151,s_domain:0.658,t_domain:0.652,time0.12331390380859375
# Test set: Average loss: 0.0002, Accuracy: 9738.0/10000 (97%)
# Test set: Average loss: 0.0022, Accuracy: 39509.0/59001 (67%)
#
# Test set: Average loss: 0.0022, Accuracy: 6043.0/9001 (67%)
#
# epoch:8,[0/116],s_label:0.142,s_domain:0.647,t_domain:0.665,time0.1253657341003418
# Test set: Average loss: 0.0002, Accuracy: 9741.0/10000 (97%)
# Test set: Average loss: 0.0020, Accuracy: 41501.0/59001 (70%)
#
# Test set: Average loss: 0.0020, Accuracy: 6341.0/9001 (70%)
#
# epoch:9,[0/116],s_label:0.143,s_domain:0.647,t_domain:0.681,time0.14659571647644043
# Test set: Average loss: 0.0001, Accuracy: 9792.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 42033.0/59001 (71%)
#
# Test set: Average loss: 0.0020, Accuracy: 6375.0/9001 (71%)
#
# epoch:10,[0/116],s_label:0.178,s_domain:0.661,t_domain:0.669,time0.13769173622131348
# Test set: Average loss: 0.0001, Accuracy: 9767.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 43015.0/59001 (73%)
#
# Test set: Average loss: 0.0018, Accuracy: 6627.0/9001 (74%)
#
# epoch:11,[0/116],s_label:0.137,s_domain:0.634,t_domain:0.674,time0.12008523941040039
# Test set: Average loss: 0.0001, Accuracy: 9777.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 43664.0/59001 (74%)
#
# Test set: Average loss: 0.0017, Accuracy: 6707.0/9001 (75%)
#
# epoch:12,[0/116],s_label:0.170,s_domain:0.677,t_domain:0.674,time0.12468361854553223
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fda10c42780>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9780.0/10000 (98%)
# Test set: Average loss: 0.0020, Accuracy: 43007.0/59001 (73%)
#
# Test set: Average loss: 0.0020, Accuracy: 6612.0/9001 (73%)
#
# epoch:13,[0/116],s_label:0.150,s_domain:0.650,t_domain:0.665,time0.1572885513305664
# Test set: Average loss: 0.0002, Accuracy: 9633.0/10000 (96%)
# Test set: Average loss: 0.0020, Accuracy: 42782.0/59001 (73%)
#
# Test set: Average loss: 0.0020, Accuracy: 6584.0/9001 (73%)
#
# epoch:14,[0/116],s_label:0.176,s_domain:0.705,t_domain:0.664,time0.11926960945129395
# Test set: Average loss: 0.0001, Accuracy: 9840.0/10000 (98%)
# Test set: Average loss: 0.0018, Accuracy: 44027.0/59001 (75%)
#
# Test set: Average loss: 0.0018, Accuracy: 6657.0/9001 (74%)
#
# epoch:15,[0/116],s_label:0.127,s_domain:0.660,t_domain:0.682,time0.13114213943481445
# Test set: Average loss: 0.0001, Accuracy: 9801.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 45188.0/59001 (77%)
#
# Test set: Average loss: 0.0016, Accuracy: 6904.0/9001 (77%)
#
# epoch:16,[0/116],s_label:0.111,s_domain:0.658,t_domain:0.661,time0.12954235076904297
# Test set: Average loss: 0.0001, Accuracy: 9811.0/10000 (98%)
# Test set: Average loss: 0.0019, Accuracy: 42690.0/59001 (72%)
#
# Test set: Average loss: 0.0018, Accuracy: 6553.0/9001 (73%)
#
# epoch:17,[0/116],s_label:0.103,s_domain:0.652,t_domain:0.667,time0.14497017860412598
# Test set: Average loss: 0.0001, Accuracy: 9808.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 46461.0/59001 (79%)
#
# Test set: Average loss: 0.0015, Accuracy: 7075.0/9001 (79%)
#
# epoch:18,[0/116],s_label:0.118,s_domain:0.657,t_domain:0.684,time0.13351035118103027
# Test set: Average loss: 0.0001, Accuracy: 9839.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 45829.0/59001 (78%)
#
# Test set: Average loss: 0.0015, Accuracy: 7006.0/9001 (78%)
#
# epoch:19,[0/116],s_label:0.121,s_domain:0.674,t_domain:0.684,time0.11825251579284668
# Test set: Average loss: 0.0001, Accuracy: 9830.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 45133.0/59001 (76%)
#
# Test set: Average loss: 0.0017, Accuracy: 6886.0/9001 (77%)
#
# epoch:20,[0/116],s_label:0.111,s_domain:0.665,t_domain:0.667,time0.16117334365844727
# Test set: Average loss: 0.0001, Accuracy: 9804.0/10000 (98%)
# Test set: Average loss: 0.0017, Accuracy: 44601.0/59001 (76%)
#
# Test set: Average loss: 0.0016, Accuracy: 6866.0/9001 (76%)
#
# epoch:21,[0/116],s_label:0.123,s_domain:0.660,t_domain:0.673,time0.1453409194946289
# Test set: Average loss: 0.0001, Accuracy: 9819.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 46278.0/59001 (78%)
#
# Test set: Average loss: 0.0014, Accuracy: 7145.0/9001 (79%)
#
# epoch:22,[0/116],s_label:0.143,s_domain:0.677,t_domain:0.688,time0.1248159408569336
# Test set: Average loss: 0.0001, Accuracy: 9836.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 46398.0/59001 (79%)
#
# Test set: Average loss: 0.0015, Accuracy: 7109.0/9001 (79%)
#
# epoch:23,[0/116],s_label:0.152,s_domain:0.665,t_domain:0.682,time0.1199803352355957
# Test set: Average loss: 0.0001, Accuracy: 9830.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 45875.0/59001 (78%)
#
# Test set: Average loss: 0.0015, Accuracy: 6989.0/9001 (78%)
#
# epoch:24,[0/116],s_label:0.076,s_domain:0.669,t_domain:0.685,time0.1214137077331543
# Test set: Average loss: 0.0001, Accuracy: 9834.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 46263.0/59001 (78%)
#
# Test set: Average loss: 0.0015, Accuracy: 7078.0/9001 (79%)
#
# epoch:25,[0/116],s_label:0.122,s_domain:0.658,t_domain:0.662,time0.11918878555297852
# Test set: Average loss: 0.0001, Accuracy: 9790.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 46158.0/59001 (78%)
#
# Test set: Average loss: 0.0015, Accuracy: 7035.0/9001 (78%)
#
# epoch:26,[0/116],s_label:0.148,s_domain:0.676,t_domain:0.686,time0.11995673179626465
# Test set: Average loss: 0.0001, Accuracy: 9809.0/10000 (98%)
# Test set: Average loss: 0.0013, Accuracy: 47381.0/59001 (80%)
#
# Test set: Average loss: 0.0013, Accuracy: 7334.0/9001 (81%)
#
# epoch:27,[0/116],s_label:0.099,s_domain:0.668,t_domain:0.669,time0.14147520065307617
# Test set: Average loss: 0.0001, Accuracy: 9838.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 47024.0/59001 (80%)
#
# Test set: Average loss: 0.0014, Accuracy: 7231.0/9001 (80%)
#
# epoch:28,[0/116],s_label:0.110,s_domain:0.676,t_domain:0.677,time0.12055063247680664
# Test set: Average loss: 0.0001, Accuracy: 9819.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 46871.0/59001 (79%)
#
# Test set: Average loss: 0.0014, Accuracy: 7204.0/9001 (80%)
#
# epoch:29,[0/116],s_label:0.165,s_domain:0.667,t_domain:0.687,time0.16338753700256348
# Test set: Average loss: 0.0001, Accuracy: 9831.0/10000 (98%)
# Test set: Average loss: 0.0013, Accuracy: 47619.0/59001 (81%)
#
# Test set: Average loss: 0.0013, Accuracy: 7343.0/9001 (82%)
#
# epoch:30,[0/116],s_label:0.115,s_domain:0.662,t_domain:0.664,time0.12737154960632324
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fda10c426a0>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9817.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 47525.0/59001 (81%)
#
# Test set: Average loss: 0.0013, Accuracy: 7324.0/9001 (81%)
#
# epoch:31,[0/116],s_label:0.073,s_domain:0.669,t_domain:0.666,time0.12107086181640625
# Test set: Average loss: 0.0001, Accuracy: 9831.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 47355.0/59001 (80%)
#
# Test set: Average loss: 0.0014, Accuracy: 7277.0/9001 (81%)
#
# epoch:32,[0/116],s_label:0.133,s_domain:0.650,t_domain:0.689,time0.12311673164367676
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fda10c42828>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9842.0/10000 (98%)
# Test set: Average loss: 0.0013, Accuracy: 47215.0/59001 (80%)
#
# Test set: Average loss: 0.0014, Accuracy: 7192.0/9001 (80%)
#
# epoch:33,[0/116],s_label:0.075,s_domain:0.682,t_domain:0.667,time0.12757134437561035
# Test set: Average loss: 0.0001, Accuracy: 9863.0/10000 (99%)
# Test set: Average loss: 0.0013, Accuracy: 48122.0/59001 (82%)
#
# Test set: Average loss: 0.0013, Accuracy: 7320.0/9001 (81%)
#
# epoch:34,[0/116],s_label:0.132,s_domain:0.676,t_domain:0.673,time0.14115500450134277
# Test set: Average loss: 0.0001, Accuracy: 9845.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 46635.0/59001 (79%)
#
# Test set: Average loss: 0.0016, Accuracy: 7183.0/9001 (80%)
#
# epoch:35,[0/116],s_label:0.134,s_domain:0.670,t_domain:0.674,time0.1454324722290039
# Test set: Average loss: 0.0001, Accuracy: 9807.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 47566.0/59001 (81%)
#
# Test set: Average loss: 0.0013, Accuracy: 7293.0/9001 (81%)
#
# epoch:36,[0/116],s_label:0.096,s_domain:0.689,t_domain:0.684,time0.12291622161865234
# Test set: Average loss: 0.0001, Accuracy: 9841.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 47633.0/59001 (81%)
#
# Test set: Average loss: 0.0013, Accuracy: 7337.0/9001 (82%)
#
# epoch:37,[0/116],s_label:0.127,s_domain:0.689,t_domain:0.679,time0.12066388130187988
# Test set: Average loss: 0.0001, Accuracy: 9829.0/10000 (98%)
# Test set: Average loss: 0.0013, Accuracy: 48022.0/59001 (81%)
#
# Test set: Average loss: 0.0013, Accuracy: 7354.0/9001 (82%)
#
# epoch:38,[0/116],s_label:0.135,s_domain:0.690,t_domain:0.671,time0.12392973899841309
# Test set: Average loss: 0.0001, Accuracy: 9845.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 47360.0/59001 (80%)
#
# Test set: Average loss: 0.0013, Accuracy: 7324.0/9001 (81%)
#
# epoch:39,[0/116],s_label:0.103,s_domain:0.666,t_domain:0.672,time0.11967945098876953
# Test set: Average loss: 0.0001, Accuracy: 9841.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 47636.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7303.0/9001 (81%)
#
# epoch:40,[0/116],s_label:0.103,s_domain:0.666,t_domain:0.661,time0.11953878402709961
# Test set: Average loss: 0.0001, Accuracy: 9853.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 47135.0/59001 (80%)
#
# Test set: Average loss: 0.0015, Accuracy: 7224.0/9001 (80%)
#
# epoch:41,[0/116],s_label:0.128,s_domain:0.668,t_domain:0.686,time0.12031793594360352
# Test set: Average loss: 0.0001, Accuracy: 9858.0/10000 (99%)
# Test set: Average loss: 0.0013, Accuracy: 47941.0/59001 (81%)
#
# Test set: Average loss: 0.0012, Accuracy: 7351.0/9001 (82%)
#
# epoch:42,[0/116],s_label:0.108,s_domain:0.674,t_domain:0.671,time0.11867785453796387
# Test set: Average loss: 0.0001, Accuracy: 9837.0/10000 (98%)
# Test set: Average loss: 0.0013, Accuracy: 47886.0/59001 (81%)
#
# Test set: Average loss: 0.0013, Accuracy: 7299.0/9001 (81%)
#
# epoch:43,[0/116],s_label:0.095,s_domain:0.675,t_domain:0.671,time0.12221360206604004
# Test set: Average loss: 0.0001, Accuracy: 9851.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 47517.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7225.0/9001 (80%)
#
# epoch:44,[0/116],s_label:0.052,s_domain:0.670,t_domain:0.665,time0.1227562427520752
# Test set: Average loss: 0.0001, Accuracy: 9855.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 47875.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7284.0/9001 (81%)
#
# epoch:45,[0/116],s_label:0.093,s_domain:0.670,t_domain:0.681,time0.1263446807861328
# Test set: Average loss: 0.0001, Accuracy: 9832.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 47146.0/59001 (80%)
#
# Test set: Average loss: 0.0016, Accuracy: 7240.0/9001 (80%)
#
# epoch:46,[0/116],s_label:0.071,s_domain:0.669,t_domain:0.681,time0.11852836608886719
# Test set: Average loss: 0.0001, Accuracy: 9858.0/10000 (99%)
# Test set: Average loss: 0.0016, Accuracy: 46785.0/59001 (79%)
#
# Test set: Average loss: 0.0015, Accuracy: 7237.0/9001 (80%)
#
# epoch:47,[0/116],s_label:0.059,s_domain:0.672,t_domain:0.671,time0.12489604949951172
# Test set: Average loss: 0.0001, Accuracy: 9855.0/10000 (99%)
# Test set: Average loss: 0.0013, Accuracy: 48121.0/59001 (82%)
#
# Test set: Average loss: 0.0013, Accuracy: 7431.0/9001 (83%)
#
# epoch:48,[0/116],s_label:0.087,s_domain:0.671,t_domain:0.670,time0.12352728843688965
# Test set: Average loss: 0.0001, Accuracy: 9841.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 47708.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7320.0/9001 (81%)
#
# epoch:49,[0/116],s_label:0.090,s_domain:0.684,t_domain:0.669,time0.11817240715026855
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fda10c42780>>
# Traceback (most recent call last):
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/coder.chenshicheng/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Test set: Average loss: 0.0001, Accuracy: 9860.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 47411.0/59001 (80%)
#
# Test set: Average loss: 0.0014, Accuracy: 7223.0/9001 (80%)
#
# epoch:50,[0/116],s_label:0.080,s_domain:0.649,t_domain:0.682,time0.11936235427856445
# Test set: Average loss: 0.0001, Accuracy: 9836.0/10000 (98%)
# Test set: Average loss: 0.0013, Accuracy: 47821.0/59001 (81%)
#
# Test set: Average loss: 0.0013, Accuracy: 7292.0/9001 (81%)
#
# epoch:51,[0/116],s_label:0.065,s_domain:0.663,t_domain:0.677,time0.11913299560546875
# Test set: Average loss: 0.0001, Accuracy: 9860.0/10000 (99%)
# Test set: Average loss: 0.0013, Accuracy: 47912.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7298.0/9001 (81%)
#
# epoch:52,[0/116],s_label:0.141,s_domain:0.666,t_domain:0.686,time0.1194753646850586
# Test set: Average loss: 0.0001, Accuracy: 9855.0/10000 (99%)
# Test set: Average loss: 0.0017, Accuracy: 46567.0/59001 (79%)
#
# Test set: Average loss: 0.0016, Accuracy: 7195.0/9001 (80%)
#
# epoch:53,[0/116],s_label:0.084,s_domain:0.675,t_domain:0.685,time0.14580368995666504
# Test set: Average loss: 0.0001, Accuracy: 9870.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 47570.0/59001 (81%)
#
# Test set: Average loss: 0.0015, Accuracy: 7284.0/9001 (81%)
#
# epoch:54,[0/116],s_label:0.095,s_domain:0.680,t_domain:0.692,time0.14603877067565918
# Test set: Average loss: 0.0001, Accuracy: 9840.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 47482.0/59001 (80%)
#
# Test set: Average loss: 0.0015, Accuracy: 7285.0/9001 (81%)
#
# epoch:55,[0/116],s_label:0.111,s_domain:0.691,t_domain:0.667,time0.12034749984741211
# Test set: Average loss: 0.0001, Accuracy: 9867.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48034.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7349.0/9001 (82%)
#
# epoch:56,[0/116],s_label:0.082,s_domain:0.664,t_domain:0.668,time0.12083935737609863
# Test set: Average loss: 0.0001, Accuracy: 9858.0/10000 (99%)
# Test set: Average loss: 0.0013, Accuracy: 48308.0/59001 (82%)
#
# Test set: Average loss: 0.0013, Accuracy: 7424.0/9001 (82%)
#
# epoch:57,[0/116],s_label:0.100,s_domain:0.680,t_domain:0.678,time0.14428019523620605
# Test set: Average loss: 0.0001, Accuracy: 9845.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 47629.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7247.0/9001 (81%)
#
# epoch:58,[0/116],s_label:0.075,s_domain:0.677,t_domain:0.657,time0.12705063819885254
# Test set: Average loss: 0.0001, Accuracy: 9811.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 48054.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7356.0/9001 (82%)
#
# epoch:59,[0/116],s_label:0.143,s_domain:0.686,t_domain:0.671,time0.16121792793273926
# Test set: Average loss: 0.0001, Accuracy: 9872.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48277.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7388.0/9001 (82%)
#
# epoch:60,[0/116],s_label:0.080,s_domain:0.656,t_domain:0.674,time0.1314992904663086
# Test set: Average loss: 0.0001, Accuracy: 9855.0/10000 (99%)
# Test set: Average loss: 0.0013, Accuracy: 48422.0/59001 (82%)
#
# Test set: Average loss: 0.0013, Accuracy: 7406.0/9001 (82%)
#
# epoch:61,[0/116],s_label:0.082,s_domain:0.675,t_domain:0.678,time0.12964892387390137
# Test set: Average loss: 0.0001, Accuracy: 9862.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48223.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7413.0/9001 (82%)
#
# epoch:62,[0/116],s_label:0.119,s_domain:0.668,t_domain:0.690,time0.1383192539215088
# Test set: Average loss: 0.0001, Accuracy: 9851.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48283.0/59001 (82%)
#
# Test set: Average loss: 0.0015, Accuracy: 7388.0/9001 (82%)
#
# epoch:63,[0/116],s_label:0.096,s_domain:0.677,t_domain:0.676,time0.12442374229431152
# Test set: Average loss: 0.0001, Accuracy: 9846.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 48190.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7477.0/9001 (83%)
#
# epoch:64,[0/116],s_label:0.078,s_domain:0.682,t_domain:0.683,time0.13007354736328125
# Test set: Average loss: 0.0001, Accuracy: 9853.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 47726.0/59001 (81%)
#
# Test set: Average loss: 0.0015, Accuracy: 7326.0/9001 (81%)
#
# epoch:65,[0/116],s_label:0.112,s_domain:0.674,t_domain:0.677,time0.11780428886413574
# Test set: Average loss: 0.0001, Accuracy: 9868.0/10000 (99%)
# Test set: Average loss: 0.0016, Accuracy: 47590.0/59001 (81%)
#
# Test set: Average loss: 0.0016, Accuracy: 7315.0/9001 (81%)
#
# epoch:66,[0/116],s_label:0.107,s_domain:0.663,t_domain:0.679,time0.12511086463928223
# Test set: Average loss: 0.0001, Accuracy: 9864.0/10000 (99%)
# Test set: Average loss: 0.0012, Accuracy: 48865.0/59001 (83%)
#
# Test set: Average loss: 0.0012, Accuracy: 7485.0/9001 (83%)
#
# epoch:67,[0/116],s_label:0.075,s_domain:0.663,t_domain:0.676,time0.12395977973937988
# Test set: Average loss: 0.0001, Accuracy: 9845.0/10000 (98%)
# Test set: Average loss: 0.0014, Accuracy: 48607.0/59001 (82%)
#
# Test set: Average loss: 0.0013, Accuracy: 7455.0/9001 (83%)
#
# epoch:68,[0/116],s_label:0.095,s_domain:0.674,t_domain:0.685,time0.12181425094604492
# Test set: Average loss: 0.0001, Accuracy: 9858.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 48202.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7433.0/9001 (83%)
#
# epoch:69,[0/116],s_label:0.103,s_domain:0.679,t_domain:0.680,time0.11900472640991211
# Test set: Average loss: 0.0001, Accuracy: 9849.0/10000 (98%)
# Test set: Average loss: 0.0013, Accuracy: 48540.0/59001 (82%)
#
# Test set: Average loss: 0.0013, Accuracy: 7451.0/9001 (83%)
#
# epoch:70,[0/116],s_label:0.085,s_domain:0.676,t_domain:0.669,time0.11917686462402344
# Test set: Average loss: 0.0001, Accuracy: 9848.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 47963.0/59001 (81%)
#
# Test set: Average loss: 0.0015, Accuracy: 7341.0/9001 (82%)
#
# epoch:71,[0/116],s_label:0.081,s_domain:0.675,t_domain:0.679,time0.13377118110656738
# Test set: Average loss: 0.0001, Accuracy: 9862.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48083.0/59001 (81%)
#
# Test set: Average loss: 0.0014, Accuracy: 7405.0/9001 (82%)
#
# epoch:72,[0/116],s_label:0.098,s_domain:0.679,t_domain:0.674,time0.15021967887878418
# Test set: Average loss: 0.0001, Accuracy: 9878.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48116.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7420.0/9001 (82%)
#
# epoch:73,[0/116],s_label:0.090,s_domain:0.668,t_domain:0.671,time0.11913585662841797
# Test set: Average loss: 0.0001, Accuracy: 9861.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48320.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7460.0/9001 (83%)
#
# epoch:74,[0/116],s_label:0.091,s_domain:0.680,t_domain:0.671,time0.11956405639648438
# Test set: Average loss: 0.0001, Accuracy: 9845.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 47847.0/59001 (81%)
#
# Test set: Average loss: 0.0015, Accuracy: 7312.0/9001 (81%)
#
# epoch:75,[0/116],s_label:0.060,s_domain:0.678,t_domain:0.685,time0.12571167945861816
# Test set: Average loss: 0.0001, Accuracy: 9844.0/10000 (98%)
# Test set: Average loss: 0.0015, Accuracy: 48127.0/59001 (82%)
#
# Test set: Average loss: 0.0015, Accuracy: 7388.0/9001 (82%)
#
# epoch:76,[0/116],s_label:0.096,s_domain:0.682,t_domain:0.683,time0.137129545211792
# Test set: Average loss: 0.0001, Accuracy: 9856.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 47988.0/59001 (81%)
#
# Test set: Average loss: 0.0015, Accuracy: 7365.0/9001 (82%)
#
# epoch:77,[0/116],s_label:0.069,s_domain:0.682,t_domain:0.673,time0.1254568099975586
# Test set: Average loss: 0.0001, Accuracy: 9842.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 48008.0/59001 (81%)
#
# Test set: Average loss: 0.0016, Accuracy: 7361.0/9001 (82%)
#
# epoch:78,[0/116],s_label:0.065,s_domain:0.664,t_domain:0.683,time0.13978815078735352
# Test set: Average loss: 0.0001, Accuracy: 9840.0/10000 (98%)
# Test set: Average loss: 0.0016, Accuracy: 47670.0/59001 (81%)
#
# Test set: Average loss: 0.0016, Accuracy: 7376.0/9001 (82%)
#
# epoch:79,[0/116],s_label:0.069,s_domain:0.666,t_domain:0.673,time0.1194448471069336
# Test set: Average loss: 0.0001, Accuracy: 9864.0/10000 (99%)
# Test set: Average loss: 0.0013, Accuracy: 48328.0/59001 (82%)
# Test set: Average loss: 0.0013, Accuracy: 7442.0/9001 (83%)
#
# epoch:80,[0/116],s_label:0.089,s_domain:0.680,t_domain:0.684,time0.14845705032348633
# Test set: Average loss: 0.0001, Accuracy: 9856.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48365.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7435.0/9001 (83%)
#
# epoch:81,[0/116],s_label:0.076,s_domain:0.686,t_domain:0.677,time0.13457345962524414
# Test set: Average loss: 0.0001, Accuracy: 9857.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48329.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7462.0/9001 (83%)
#
# epoch:82,[0/116],s_label:0.078,s_domain:0.688,t_domain:0.686,time0.17340993881225586
# Test set: Average loss: 0.0001, Accuracy: 9850.0/10000 (98%)
# Test set: Average loss: 0.0013, Accuracy: 48596.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7463.0/9001 (83%)
#
# epoch:83,[0/116],s_label:0.066,s_domain:0.667,t_domain:0.678,time0.11987948417663574
# Test set: Average loss: 0.0001, Accuracy: 9857.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48353.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7447.0/9001 (83%)
#
# epoch:84,[0/116],s_label:0.091,s_domain:0.682,t_domain:0.685,time0.12420034408569336
# Test set: Average loss: 0.0001, Accuracy: 9872.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48294.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7411.0/9001 (82%)
#
# epoch:85,[0/116],s_label:0.074,s_domain:0.671,t_domain:0.673,time0.11983346939086914
# Test set: Average loss: 0.0001, Accuracy: 9875.0/10000 (99%)
# Test set: Average loss: 0.0016, Accuracy: 48004.0/59001 (81%)
#
# Test set: Average loss: 0.0015, Accuracy: 7371.0/9001 (82%)
#
# epoch:86,[0/116],s_label:0.091,s_domain:0.679,t_domain:0.681,time0.1404249668121338
# Test set: Average loss: 0.0001, Accuracy: 9878.0/10000 (99%)
# Test set: Average loss: 0.0017, Accuracy: 47800.0/59001 (81%)
#
# Test set: Average loss: 0.0017, Accuracy: 7358.0/9001 (82%)
#
# epoch:87,[0/116],s_label:0.077,s_domain:0.668,t_domain:0.682,time0.12553787231445312
# Test set: Average loss: 0.0001, Accuracy: 9878.0/10000 (99%)
# Test set: Average loss: 0.0018, Accuracy: 47269.0/59001 (80%)
#
# Test set: Average loss: 0.0018, Accuracy: 7262.0/9001 (81%)
#
# epoch:88,[0/116],s_label:0.095,s_domain:0.669,t_domain:0.682,time0.11932635307312012
# Test set: Average loss: 0.0001, Accuracy: 9872.0/10000 (99%)
# Test set: Average loss: 0.0018, Accuracy: 47696.0/59001 (81%)
#
# Test set: Average loss: 0.0018, Accuracy: 7310.0/9001 (81%)
#
# epoch:89,[0/116],s_label:0.094,s_domain:0.670,t_domain:0.683,time0.12328553199768066
# Test set: Average loss: 0.0001, Accuracy: 9863.0/10000 (99%)
# Test set: Average loss: 0.0016, Accuracy: 48296.0/59001 (82%)
#
# Test set: Average loss: 0.0016, Accuracy: 7422.0/9001 (82%)
#
# epoch:90,[0/116],s_label:0.092,s_domain:0.668,t_domain:0.681,time0.12370705604553223
# Test set: Average loss: 0.0001, Accuracy: 9855.0/10000 (99%)
# Test set: Average loss: 0.0013, Accuracy: 48788.0/59001 (83%)
#
# Test set: Average loss: 0.0013, Accuracy: 7471.0/9001 (83%)
#
# epoch:91,[0/116],s_label:0.084,s_domain:0.673,t_domain:0.680,time0.14579272270202637
# Test set: Average loss: 0.0001, Accuracy: 9863.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 48407.0/59001 (82%)
#
# Test set: Average loss: 0.0015, Accuracy: 7400.0/9001 (82%)
#
# epoch:92,[0/116],s_label:0.066,s_domain:0.676,t_domain:0.685,time0.13017725944519043
# Test set: Average loss: 0.0001, Accuracy: 9865.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 48227.0/59001 (82%)
#
# Test set: Average loss: 0.0015, Accuracy: 7389.0/9001 (82%)
#
# epoch:93,[0/116],s_label:0.071,s_domain:0.665,t_domain:0.688,time0.15364527702331543
# Test set: Average loss: 0.0001, Accuracy: 9867.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 48030.0/59001 (81%)
#
# Test set: Average loss: 0.0015, Accuracy: 7390.0/9001 (82%)
#
# epoch:94,[0/116],s_label:0.086,s_domain:0.675,t_domain:0.681,time0.13588905334472656
# Test set: Average loss: 0.0001, Accuracy: 9879.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48419.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7412.0/9001 (82%)
#
# epoch:95,[0/116],s_label:0.057,s_domain:0.682,t_domain:0.662,time0.16162562370300293
# Test set: Average loss: 0.0001, Accuracy: 9864.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 48248.0/59001 (82%)
#
# Test set: Average loss: 0.0015, Accuracy: 7410.0/9001 (82%)
#
# epoch:96,[0/116],s_label:0.049,s_domain:0.677,t_domain:0.687,time0.11948966979980469
# Test set: Average loss: 0.0001, Accuracy: 9862.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 48310.0/59001 (82%)
#
# Test set: Average loss: 0.0015, Accuracy: 7434.0/9001 (83%)
#
# epoch:97,[0/116],s_label:0.054,s_domain:0.685,t_domain:0.677,time0.12460803985595703
# Test set: Average loss: 0.0001, Accuracy: 9856.0/10000 (99%)
# Test set: Average loss: 0.0016, Accuracy: 48119.0/59001 (82%)
#
# Test set: Average loss: 0.0015, Accuracy: 7449.0/9001 (83%)
#
# epoch:98,[0/116],s_label:0.082,s_domain:0.676,t_domain:0.690,time0.12195944786071777
# Test set: Average loss: 0.0001, Accuracy: 9869.0/10000 (99%)
# Test set: Average loss: 0.0015, Accuracy: 48559.0/59001 (82%)
#
# Test set: Average loss: 0.0015, Accuracy: 7474.0/9001 (83%)
#
# epoch:99,[0/116],s_label:0.102,s_domain:0.665,t_domain:0.692,time0.13418340682983398
# Test set: Average loss: 0.0001, Accuracy: 9869.0/10000 (99%)
# Test set: Average loss: 0.0014, Accuracy: 48521.0/59001 (82%)
#
# Test set: Average loss: 0.0014, Accuracy: 7501.0/9001 (83%)
